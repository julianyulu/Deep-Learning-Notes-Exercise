# %% [markdown]
# # About
# This notebook is from Udacity Deep Learning Course

# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'as', 'of', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.269217
# Nearest to has: connie, sample, gujarat, commits, tanistry, mellow, debasement, destruction,
# Nearest to other: nth, trickster, oldies, imprinted, mcclintock, baud, vetoes, plurality,
# Nearest to one: disagreed, dect, encircle, knighthood, rancho, qualified, tommy, polly,
# Nearest to american: lenten, sufficed, iww, additive, aediles, melilla, modernize, dactylic,
# Nearest to years: preceded, cosmetics, kingpin, protectionism, tribal, insurrection, wipes, surreal,
# Nearest to his: shipbuilding, reproduce, cvd, goldstein, prepaid, presheaf, albanians, gouvernement,
# Nearest to more: synergy, grumman, bloodiest, schellenberg, stanza, calculators, mestizo, rubble,
# Nearest to seven: frei, spaces, carrots, soybeans, widdecombe, broadcaster, esdras, hallucinogen,
# Nearest to five: wexford, certainly, sabra, hydrates, denial, viceroy, seminole, heralded,
# Nearest to new: tiki, florentine, straining, dilbert, ojibwe, wakko, diets, betrothal,
# Nearest to they: jackal, salome, exempted, mckernan, electrophysiology, ailment, decreased, valeria,
# Nearest to united: gagauz, straight, globalsecurity, cow, archery, zhu, overflow, positioning,
# Nearest to their: calls, clinic, accumulated, trypomastigotes, bebe, extremity, venous, hander,
# Nearest to known: wladislaus, swallows, directors, millennium, bracket, landslides, niven, convicts,
# Nearest to an: laotian, supermarkets, rsc, confessed, digests, insulinotherapy, torr, mosiah,
# Nearest to if: dysrhythmias, parmenides, acrobat, route, aichi, greasy, gilbert, herbicide,
# Average loss at step 2000: 4.373716
# Average loss at step 4000: 3.862217
# Average loss at step 6000: 3.790353
# Average loss at step 8000: 3.689230
# Average loss at step 10000: 3.613818
# Nearest to has: had, have, was, is, comprehensively, vigilant, gelasian, hdi,
# Nearest to other: imprinted, salinas, manley, routes, baud, pep, nth, concepts,
# Nearest to one: two, seven, three, four, eight, five, six, isbn,
# Nearest to american: eli, procol, pattie, aediles, dactylic, and, mchenry, humphreys,
# Nearest to years: reaching, mortars, preceded, moderators, insurrection, aureus, kingpin, wipes,
# Nearest to his: her, their, s, the, its, this, hypothermia, eo,
# Nearest to more: moisture, horthy, bloodiest, calculators, hyperinflation, happened, polypropylene, lower,
# Nearest to seven: eight, six, five, three, four, nine, zero, two,
# Nearest to five: seven, six, eight, four, three, nine, two, zero,
# Nearest to new: betrothal, equatorial, dflp, sanctify, salman, conservatory, fantasyland, derisively,
# Nearest to they: he, it, who, valeria, we, micas, indulgent, not,
# Nearest to united: zhu, tribute, acquaintance, straight, lao, archery, qt, contesting,
# Nearest to their: his, accumulated, cruz, its, this, subpixels, trypomastigotes, approximations,
# Nearest to known: another, abandons, well, millennium, muscovy, oxidizes, programmer, wladislaus,
# Nearest to an: digests, nukem, matres, david, insulinotherapy, tobago, agassi, the,
# Nearest to if: lastly, route, aichi, stacked, dysrhythmias, carnivorous, wrote, parmenides,
# Average loss at step 12000: 3.605975
# Average loss at step 14000: 3.568123
# Average loss at step 16000: 3.404040
# Average loss at step 18000: 3.457738
# Average loss at step 20000: 3.537738
# Nearest to has: had, was, have, is, having, vigilant, doomsday, comprehensively,
# Nearest to other: many, some, salinas, routes, these, manley, imprinted, various,
# Nearest to one: two, three, four, seven, eight, six, five, dub,
# Nearest to american: procol, program, eli, disadvantageous, expandable, humphreys, pattie, british,
# Nearest to years: reaching, paso, wipes, world, preceded, moderators, aboriginal, diagonally,
# Nearest to his: their, her, its, the, liberians, this, hypothermia, some,
# Nearest to more: most, less, lower, happened, very, horthy, calculators, moisture,
# Nearest to seven: eight, six, five, three, nine, four, zero, two,
# Nearest to five: seven, four, six, three, zero, eight, two, nine,
# Nearest to new: equatorial, sanctify, fantasyland, conservatory, dflp, axum, freenode, ojibwe,
# Nearest to they: he, we, it, who, there, indulgent, micas, valeria,
# Nearest to united: zhu, tribute, straight, alle, acquaintance, qt, gluconeogenesis, contesting,
# Nearest to their: his, its, the, her, tiglath, plotline, accumulated, cruz,
# Nearest to known: used, abandons, such, waldemar, well, muscovy, another, programmer,
# Nearest to an: digests, agassi, tobago, the, nukem, dinosauria, corey, bloomsbury,
# Nearest to if: lastly, when, aichi, evidentiary, route, carnivorous, though, is,
# Average loss at step 22000: 3.505043
# Average loss at step 24000: 3.489575
# Average loss at step 26000: 3.482515
# Average loss at step 28000: 3.479576
# Average loss at step 30000: 3.506730
# Nearest to has: had, have, is, was, having, comprehensively, kyrenia, hdi,
# Nearest to other: these, various, many, some, such, salinas, routes, different,
# Nearest to one: two, seven, six, four, eight, five, three, nine,
# Nearest to american: british, english, austrian, italian, disadvantageous, procol, german, pattie,
# Nearest to years: reaching, decades, year, bc, hours, teos, greatness, days,
# Nearest to his: her, their, its, s, the, liberians, accumulated, him,
# Nearest to more: less, most, very, lower, calculators, greater, larger, irregularity,
# Nearest to seven: eight, nine, five, six, four, three, zero, two,
# Nearest to five: four, eight, seven, six, three, nine, zero, two,
# Nearest to new: salman, fantasyland, equatorial, sanctify, cooling, demonstrably, guerrero, hippolyte,
# Nearest to they: he, we, there, it, who, you, indulgent, these,
# Nearest to united: zhu, gluconeogenesis, contesting, clarinets, hades, straight, alle, acquaintance,
# Nearest to their: his, its, the, her, tiglath, accumulated, these, runoff,
# Nearest to known: used, well, such, abandons, waldemar, muscovy, seen, responsible,
# Nearest to an: digests, dinosauria, infertile, torr, agassi, betrayed, corey, tobago,
# Nearest to if: when, because, though, lastly, where, but, is, quotation,
# Average loss at step 32000: 3.500536
# Average loss at step 34000: 3.494983
# Average loss at step 36000: 3.450142
# Average loss at step 38000: 3.301638
# Average loss at step 40000: 3.422249
# Nearest to has: had, have, is, was, graft, previously, unless, having,
# Nearest to other: various, different, some, salinas, many, thermionic, such, fouls,
# Nearest to one: seven, eight, four, two, six, five, nine, three,
# Nearest to american: british, australian, english, disadvantageous, canadian, atlantic, german, local,
# Nearest to years: decades, days, months, year, times, reaching, minutes, bc,
# Nearest to his: their, her, its, s, the, liberians, him, accumulated,
# Nearest to more: less, most, very, smaller, lower, larger, greater, better,
# Nearest to seven: five, eight, six, nine, four, three, two, zero,
# Nearest to five: seven, six, four, eight, zero, three, nine, two,
# Nearest to new: salman, sanctify, rebound, wwf, equatorial, cooling, conservatory, bremerhaven,
# Nearest to they: we, he, there, you, it, who, these, not,
# Nearest to united: zhu, alle, hades, clarinets, gluconeogenesis, bordering, contesting, fascist,
# Nearest to their: its, his, her, the, tiglath, these, some, accumulated,
# Nearest to known: used, such, well, abandons, waldemar, described, responsible, programmer,
# Nearest to an: dinosauria, digests, tobago, agassi, dubai, considerable, nukem, bypassing,
# Nearest to if: when, where, is, because, though, lastly, for, clin,
# Average loss at step 42000: 3.435489
# Average loss at step 44000: 3.457408
# Average loss at step 46000: 3.445100
# Average loss at step 48000: 3.354988
# Average loss at step 50000: 3.383691
# Nearest to has: had, have, is, was, unless, graft, previously, clitoridectomy,
# Nearest to other: various, some, many, different, brane, literacy, influential, macrocosm,
# Nearest to one: two, six, seven, eight, three, five, four, nine,
# Nearest to american: australian, english, british, disadvantageous, atlantic, local, canadian, articulate,
# Nearest to years: days, decades, months, times, year, minutes, hours, diagonally,
# Nearest to his: their, her, its, my, s, the, him, liberians,
# Nearest to more: less, most, very, smaller, larger, rather, highly, lower,
# Nearest to seven: eight, six, four, nine, three, five, zero, two,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to new: demonstrably, jts, salman, wwf, cooling, axum, equatorial, sanctify,
# Nearest to they: he, we, there, you, it, who, not, she,
# Nearest to united: zhu, hades, clarinets, alle, olympic, gluconeogenesis, bordering, acquaintance,
# Nearest to their: its, his, her, the, runoff, s, tiglath, gyro,
# Nearest to known: used, such, well, described, waldemar, defined, abandons, viewed,
# Nearest to an: digests, dinosauria, agassi, hippolytus, another, gian, tobago, dubai,
# Nearest to if: when, where, though, although, while, because, lastly, will,
# Average loss at step 52000: 3.436634
# Average loss at step 54000: 3.432035
# Average loss at step 56000: 3.440039
# Average loss at step 58000: 3.397250
# Average loss at step 60000: 3.391421
# Nearest to has: had, have, was, is, includes, unless, comprehensively, fathered,
# Nearest to other: various, many, different, some, pardoned, fouls, several, those,
# Nearest to one: two, five, six, four, eight, seven, three, nine,
# Nearest to american: british, australian, english, disadvantageous, atlantic, local, canadian, italian,
# Nearest to years: days, decades, months, times, year, minutes, hours, centuries,
# Nearest to his: her, their, its, my, liberians, cryonicists, him, your,
# Nearest to more: less, smaller, most, very, better, rather, larger, highly,
# Nearest to seven: eight, four, nine, six, five, three, zero, one,
# Nearest to five: four, six, three, eight, seven, nine, zero, two,
# Nearest to new: demonstrably, axum, sanctify, wwf, servants, fantasyland, flatland, salman,
# Nearest to they: we, there, you, he, it, she, i, exempted,
# Nearest to united: zhu, hades, acquaintance, alle, cow, bordering, olympic, clarinets,
# Nearest to their: its, his, her, the, some, tiglath, whose, these,
# Nearest to known: used, such, described, defined, well, waldemar, responsible, hush,
# Nearest to an: digests, tobago, nukem, agassi, gian, popeye, payne, dubai,
# Nearest to if: when, where, though, because, then, although, since, before,
# Average loss at step 62000: 3.243497
# Average loss at step 64000: 3.255380
# Average loss at step 66000: 3.401292
# Average loss at step 68000: 3.396874
# Average loss at step 70000: 3.362045
# Nearest to has: had, have, is, was, comprehensively, since, unless, although,
# Nearest to other: various, different, salinas, others, some, these, away, macrocosm,
# Nearest to one: two, seven, six, four, eight, five, three, nine,
# Nearest to american: british, australian, english, disadvantageous, atlantic, italian, entrails, canadian,
# Nearest to years: days, decades, months, times, minutes, year, centuries, hours,
# Nearest to his: her, their, its, my, liberians, him, your, the,
# Nearest to more: less, most, smaller, very, larger, highly, rather, longer,
# Nearest to seven: six, eight, four, five, nine, three, zero, two,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to new: sanctify, staley, salman, axum, tadeusz, demonstrably, jts, wwf,
# Nearest to they: we, he, there, you, it, she, then, i,
# Nearest to united: zhu, hades, bordering, alle, cow, highest, acquaintance, archery,
# Nearest to their: its, his, her, the, some, slip, these, tiglath,
# Nearest to known: used, such, described, defined, viewed, well, seen, waldemar,
# Nearest to an: digests, dubai, agassi, crippled, dinosauria, chamada, torr, the,
# Nearest to if: when, though, where, because, although, however, while, then,
# Average loss at step 72000: 3.374277
# Average loss at step 74000: 3.351707
# Average loss at step 76000: 3.311210
# Average loss at step 78000: 3.352944
# Average loss at step 80000: 3.380918
# Nearest to has: had, have, is, was, includes, caffeine, since, having,
# Nearest to other: various, others, different, some, several, brane, many, pacifica,
# Nearest to one: six, seven, two, eight, three, four, five, nine,
# Nearest to american: british, australian, irish, canadian, international, english, christiania, atlantic,
# Nearest to years: days, months, decades, minutes, times, year, hours, weeks,
# Nearest to his: her, their, its, my, liberians, your, our, the,
# Nearest to more: less, very, most, smaller, larger, rather, longer, highly,
# Nearest to seven: five, six, eight, four, nine, three, zero, one,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to new: sanctify, fantasyland, regnal, wwf, axum, lir, bremerhaven, staley,
# Nearest to they: we, he, there, you, it, she, who, these,
# Nearest to united: zhu, hades, bordering, alle, nag, citigroup, highest, archery,
# Nearest to their: its, his, her, our, the, tiglath, your, them,
# Nearest to known: used, defined, described, called, seen, such, viewed, regarded,
# Nearest to an: agassi, crippled, digests, chamada, dubai, dinosauria, considerable, tobago,
# Nearest to if: when, though, since, where, because, then, before, after,
# Average loss at step 82000: 3.407744
# Average loss at step 84000: 3.407752
# Average loss at step 86000: 3.385908
# Average loss at step 88000: 3.349386
# Average loss at step 90000: 3.363901
# Nearest to has: had, have, is, was, includes, having, kyrenia, since,
# Nearest to other: various, different, macrocosm, individual, others, brane, rank, salinas,
# Nearest to one: two, seven, four, eight, three, six, five, nine,
# Nearest to american: british, australian, italian, european, christiania, canadian, disadvantageous, irish,
# Nearest to years: days, months, decades, minutes, hours, year, times, weeks,
# Nearest to his: her, their, its, my, your, our, the, liberians,
# Nearest to more: less, very, most, smaller, larger, rather, better, longer,
# Nearest to seven: eight, six, four, five, nine, three, zero, one,
# Nearest to five: four, seven, eight, six, three, nine, zero, two,
# Nearest to new: cover, unarable, sanctify, fantasyland, old, lir, recent, staley,
# Nearest to they: we, he, there, you, she, it, soon, these,
# Nearest to united: zhu, hades, alle, bordering, uk, citigroup, constitution, archery,
# Nearest to their: its, his, her, our, your, tiglath, whose, the,
# Nearest to known: used, described, such, defined, called, seen, viewed, well,
# Nearest to an: digests, considerable, nukem, chamada, hippolytus, dubai, gian, agassi,
# Nearest to if: when, since, where, though, although, after, before, prophesied,
# Average loss at step 92000: 3.400249
# Average loss at step 94000: 3.249879
# Average loss at step 96000: 3.358011
# Average loss at step 98000: 3.241254
# Average loss at step 100000: 3.356333
# Nearest to has: had, have, is, was, includes, since, having, hdi,
# Nearest to other: various, others, brane, individual, macrocosm, different, rhythms, older,
# Nearest to one: two, four, seven, eight, five, three, six, nine,
# Nearest to american: british, australian, italian, canadian, dactylic, irish, french, incomes,
# Nearest to years: days, months, decades, minutes, hours, year, times, centuries,
# Nearest to his: her, their, my, its, your, the, our, s,
# Nearest to more: less, most, very, larger, smaller, better, highly, rather,
# Nearest to seven: eight, six, four, five, nine, three, two, zero,
# Nearest to five: four, six, seven, eight, three, two, zero, nine,
# Nearest to new: cover, fantasyland, unarable, sanctify, staley, zoo, lir, different,
# Nearest to they: we, he, there, you, she, it, i, these,
# Nearest to united: zhu, alle, hades, bordering, uk, citigroup, olympian, borzoi,
# Nearest to their: its, his, her, your, our, the, tiglath, whose,
# Nearest to known: used, such, defined, described, seen, viewed, available, called,
# Nearest to an: chamada, agassi, digests, considerable, dubai, payne, gian, sequestered,
# Nearest to if: when, though, where, although, while, since, then, prophesied,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
